# %% [markdown]
# <a href="https://colab.research.google.com/github/HugoSilvaRodrigues/AED/blob/main/Modelo_Melhorado_importPickle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# Imports para visualização de dados
import matplotlib.pyplot as plt
import seaborn as sns

# Imports para modelagem estatística
import pylab
import scipy
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.regression.linear_model as smf
import statsmodels.stats.api as sms
from scipy.stats import pearsonr
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.compat import lzip

# Import para divisão dos dados
import sklearn
from sklearn.model_selection import train_test_split


from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
rentals=pd.read_csv("/content/drive/MyDrive/AED/PROJETO/rentals.csv", index_col=False, usecols=['latitude', 'longitude', 'property_type', 'room_type',
       'bathrooms', 'bedrooms', 'minimum_nights', 'price'])

# %% [markdown]
# #Analise dos dados

# %%
rentals.head()
# Out:
#    latitude  longitude property_type        room_type  bathrooms  bedrooms  \
# 0  37.76931 -122.43386     Apartment  Entire home/apt        1.0       1.0
# 1  37.75402 -122.45805         House     Private room        1.0       1.0
# 2  37.74511 -122.42102     Apartment  Entire home/apt        1.0       2.0
# 3  37.76669 -122.45250     Apartment     Private room        4.0       1.0
# 4  37.76487 -122.45183     Apartment     Private room        4.0       1.0
#
#    minimum_nights     price
# 0               1  $170.00
# 1               1   $99.00
# 2              30  $235.00
# 3              32   $65.00
# 4              32   $65.00

# %%
rentals2=rentals.copy()

# %%
rentals.shape
# Out:
# (8111, 8)

# %%
rentals.dtypes
# Out:
# latitude          float64
# longitude         float64
# property_type      object
# room_type          object
# bathrooms         float64
# bedrooms          float64
# minimum_nights      int64
# price              object
# dtype: object

# %%
rentals['price']
rentals['price']=rentals['price'].str.strip("$")
rentals['price']=rentals['price'].str.strip(" ")
rentals['price']=rentals['price'].str.replace(',','')
rentals['price']=rentals['price'].astype(float)

# %%
rentals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8111 entries, 0 to 8110
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   latitude        8111 non-null   float64
#  1   longitude       8111 non-null   float64
#  2   property_type   8111 non-null   object
#  3   room_type       8111 non-null   object
#  4   bathrooms       8099 non-null   float64
#  5   bedrooms        8107 non-null   float64
#  6   minimum_nights  8111 non-null   int64
#  7   price           8111 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 507.1+ KB

# %% [markdown]
# *   Tem valores ausentes

# %%
rentals.dropna(inplace=True)
rentals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8095 entries, 0 to 8110
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   latitude        8095 non-null   float64
#  1   longitude       8095 non-null   float64
#  2   property_type   8095 non-null   object
#  3   room_type       8095 non-null   object
#  4   bathrooms       8095 non-null   float64
#  5   bedrooms        8095 non-null   float64
#  6   minimum_nights  8095 non-null   int64
#  7   price           8095 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 569.2+ KB

# %%
rentals.describe()
# Out:
#           latitude    longitude    bathrooms     bedrooms  minimum_nights  \
# count  8095.000000  8095.000000  8095.000000  8095.000000    8.095000e+03
# mean     37.766017  -122.430126     1.395862     1.346387    1.236963e+04
# std       0.022937     0.026974     0.923114     0.925888    1.111454e+06
# min      37.704630  -122.513060     0.000000     0.000000    1.000000e+00
# 25%      37.751430  -122.442855     1.000000     1.000000    2.000000e+00
# 50%      37.769090  -122.424670     1.000000     1.000000    4.000000e+00
# 75%      37.785600  -122.410625     1.500000     2.000000    3.000000e+01
# max      37.828790  -122.368570    14.000000    14.000000    1.000000e+08
#
#               price
# count   8095.000000
# mean     225.646325
# std      412.575797
# min        0.000000
# 25%      100.000000
# 50%      150.000000
# 75%      240.000000
# max    10000.000000

# %%
rentals.skew(axis = 0)
# Out:
# <ipython-input-124-ff44421a3196>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   rentals.skew(axis = 0)
# latitude          -0.445444
# longitude         -0.959394
# bathrooms          4.414721
# bedrooms           1.569869
# minimum_nights    89.972218
# price             16.152055
# dtype: float64

# %%
rentals.minimum_nights.value_counts(dropna=True)
# Out:
# 30           3262
# 2            1553
# 1            1422
# 3             863
# 4             322
# 5             216
# 31            114
# 7              74
# 32             60
# 60             40
# 6              36
# 90             31
# 180            18
# 14             10
# 365             9
# 13              4
# 120             4
# 21              4
# 10              4
# 183             3
# 360             3
# 50              3
# 80              3
# 18              2
# 29              2
# 45              2
# 58              2
# 8               2
# 75              2
# 40              2
# 100             1
# 1000            1
# 65              1
# 15              1
# 12              1
# 38              1
# 25              1
# 11              1
# 150             1
# 188             1
# 59              1
# 100000000       1
# 85              1
# 1125            1
# 28              1
# 140             1
# 55              1
# 110             1
# 16              1
# 70              1
# 200             1
# 9               1
# 33              1
# Name: minimum_nights, dtype: int64

# %%
rentals['minimum_nights'] = np.log(rentals['minimum_nights'])

# %%
rentals.minimum_nights.value_counts(dropna=True)
# Out:
# 3.401197     3262
# 0.693147     1553
# 0.000000     1422
# 1.098612      863
# 1.386294      322
# 1.609438      216
# 3.433987      114
# 1.945910       74
# 3.465736       60
# 4.094345       40
# 1.791759       36
# 4.499810       31
# 5.192957       18
# 2.639057       10
# 5.899897        9
# 2.564949        4
# 4.787492        4
# 3.044522        4
# 2.302585        4
# 5.209486        3
# 5.886104        3
# 3.912023        3
# 4.382027        3
# 2.890372        2
# 3.367296        2
# 3.806662        2
# 4.060443        2
# 2.079442        2
# 4.317488        2
# 3.688879        2
# 4.605170        1
# 6.907755        1
# 4.174387        1
# 2.708050        1
# 2.484907        1
# 3.637586        1
# 3.218876        1
# 2.397895        1
# 5.010635        1
# 5.236442        1
# 4.077537        1
# 18.420681       1
# 4.442651        1
# 7.025538        1
# 3.332205        1
# 4.941642        1
# 4.007333        1
# 4.700480        1
# 2.772589        1
# 4.248495        1
# 5.298317        1
# 2.197225        1
# 3.496508        1
# Name: minimum_nights, dtype: int64

# %%
rentals.skew(axis = 0)
# Out:
# <ipython-input-128-ff44421a3196>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   rentals.skew(axis = 0)
# latitude          -0.445444
# longitude         -0.959394
# bathrooms          4.414721
# bedrooms           1.569869
# minimum_nights     0.237254
# price             16.152055
# dtype: float64

# %%
rentals.columns
# Out:
# Index(['latitude', 'longitude', 'property_type', 'room_type', 'bathrooms',
#        'bedrooms', 'minimum_nights', 'price'],
#       dtype='object')

# %%
plt.figure(figsize = (7, 4))
sns.histplot(data = rentals, x = rentals['bedrooms'], kde = True)
plt.show()

# %% [markdown]
# *   Maioria das casas com 1 quarto

# %%
plt.figure(figsize = (7, 4))
sns.histplot(data = rentals, x = rentals['bathrooms'], kde = True)
plt.show()

# %% [markdown]
# *   Maioria das casas com 1 banheiro

# %%
plt.figure(figsize = (14, 6))
sns.histplot(data = rentals, x = rentals['property_type'], kde = True)
plt.xticks(rotation=55)
plt.show()

# %% [markdown]
# Maioria das propiedades são do tipo Apartamento e casa

# %%
rentals.corr()
# Out:
# <ipython-input-133-b8fbe2a52e05>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   rentals.corr()
#                 latitude  longitude  bathrooms  bedrooms  minimum_nights  \
# latitude        1.000000   0.187000   0.078469 -0.108647        0.176787
# longitude       0.187000   1.000000   0.007627 -0.115893        0.114537
# bathrooms       0.078469   0.007627   1.000000  0.327916        0.029689
# bedrooms       -0.108647  -0.115893   0.327916  1.000000       -0.002005
# minimum_nights  0.176787   0.114537   0.029689 -0.002005        1.000000
# price           0.083231   0.015867   0.081981  0.262343       -0.073196
#
#                    price
# latitude        0.083231
# longitude       0.015867
# bathrooms       0.081981
# bedrooms        0.262343
# minimum_nights -0.073196
# price           1.000000

# %%
plt.figure(figsize = (12,8))
sns.heatmap(rentals.corr(), annot = True, fmt = '.2f', cmap = 'Reds', vmax = .99, vmin = -0.60)
plt.show()
# Out:
# <ipython-input-134-8f507fee041d>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(rentals.corr(), annot = True, fmt = '.2f', cmap = 'Reds', vmax = .99, vmin = -0.60)

# %%
plt.figure(figsize = (7, 7))
sns.regplot(x = 'bedrooms', y = 'bathrooms', data = rentals, color = 'green')
plt.show()

# %% [markdown]
# Quanto mais quarto mais banheiro

# %%
plt.figure(figsize = (7, 7))
sns.regplot(x = 'bedrooms', y = 'price', data = rentals, color = 'green')
plt.show()

# %%
plt.figure(figsize = (7, 7))
sns.regplot(x = 'bathrooms', y = 'price', data = rentals, color = 'green')
plt.show()

# %% [markdown]
# Mais quarto mais caro a diaria

# %% [markdown]
# #Removendo outliers

# %% [markdown]
# ##Property type

# %%
print(rentals.property_type.value_counts())
# Out:
# Apartment             3234
# House                 2313
# Condominium            892
# Guest suite            577
# Boutique hotel         267
# Hotel                  157
# Townhouse              142
# Serviced apartment     121
# Loft                    88
# Hostel                  86
# Bed and breakfast       43
# Guesthouse              41
# Aparthotel              41
# Other                   24
# Bungalow                17
# Resort                  14
# Cottage                 12
# Villa                   10
# Castle                   4
# Cabin                    3
# Tiny house               3
# Earth house              2
# In-law                   1
# Camper/RV                1
# Dome house               1
# Hut                      1
# Name: property_type, dtype: int64

# %% [markdown]
# ##Bedrooms

# %%
sns.boxplot(x=rentals['bedrooms'])
print(rentals['bedrooms'].value_counts().astype(int))
# Out:
# 1.0     4833
# 2.0     1472
# 0.0      854
# 3.0      694
# 4.0      193
# 5.0       37
# 6.0        9
# 14.0       1
# 7.0        1
# 8.0        1
# Name: bedrooms, dtype: int64

# %%
drop=[14,7,8]
rentals['bedrooms']=rentals['bedrooms'].astype(int)
for i in drop:
	rentals=rentals.drop(rentals[rentals.bedrooms == i].index)

# %% [markdown]
# ##Bathrooms

# %%
sns.boxplot(x=rentals['bathrooms'])
print(rentals['bathrooms'].astype(int).value_counts())
# Out:
# 1     6247
# 2     1345
# 3      211
# 5      113
# 4       73
# 0       55
# 10      19
# 8       14
# 6       10
# 7        5
# Name: bathrooms, dtype: int64

# %%
rentals=rentals.drop(rentals[rentals.bathrooms == 7].index)
rentals['bedrooms']=rentals['bedrooms'].astype(int)

# %% [markdown]
# ##Minimum Nights

# %% [markdown]
# ##Price

# %%
aux2=list(rentals.price.value_counts().index)

# %%
drop_3=aux2[230:]
for i in drop_3:
    rentals=rentals.drop(rentals[rentals.price==i].index)

rentals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7434 entries, 0 to 8110
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   latitude        7434 non-null   float64
#  1   longitude       7434 non-null   float64
#  2   property_type   7434 non-null   object
#  3   room_type       7434 non-null   object
#  4   bathrooms       7434 non-null   float64
#  5   bedrooms        7434 non-null   int64
#  6   minimum_nights  7434 non-null   float64
#  7   price           7434 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 522.7+ KB

# %%
print(rentals.property_type.value_counts())
print(rentals.room_type.value_counts())
# Out:
# Apartment             2948
# House                 2134
# Condominium            806
# Guest suite            560
# Boutique hotel         250
# Hotel                  149
# Townhouse              125
# Serviced apartment     108
# Loft                    80
# Hostel                  75
# Guesthouse              40
# Bed and breakfast       38
# Aparthotel              35
# Other                   24
# Bungalow                17
# Cottage                 11
# Resort                  11
# Villa                    8
# Castle                   4
# Cabin                    3
# Tiny house               3
# Earth house              2
# In-law                   1
# Dome house               1
# Hut                      1
# Name: property_type, dtype: int64
# Entire home/apt    4239
# Private room       2792
# Shared room         221
# Hotel room          182
# Name: room_type, dtype: int64

# %%
import folium
import pandas as pd
from IPython.display import display


# Criar um mapa inicial com base nas coordenadas de latitude e longitude
mapa = folium.Map(location=[0, 0], zoom_start=2)  # Coordenadas iniciais e nível de zoom

rentals_grafico=rentals.head(1000)

# Percorrer as linhas do dataframe
for index, row in rentals_grafico.iterrows():
    # Obter as coordenadas de latitude e longitude da linha atual
    latitude = row['latitude']
    longitude = row['longitude']

    # Adicionar marcador de latitude e longitude ao mapa
    marcador = folium.Marker(location=[latitude, longitude], popup='Localização')
    marcador.add_to(mapa)

# Exibir o mapa
display(mapa)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56d7ebb77a5d150abd614ade404f4c9e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56d7ebb77a5d150abd614ade404f4c9e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56d7ebb77a5d150abd614ade404f4c9e = L.map(
#                 &quot;map_56d7ebb77a5d150abd614ade404f4c9e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e394608f8bd8faf7001620c6c8cbaa9c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_56d7ebb77a5d150abd614ade404f4c9e);
#
#
#             var marker_d68d531e23cfed4d3050282cdce90361 = L.marker(
#                 [37.76931, -122.43386],
#                 {}
#             ).addTo(map_56d7ebb77a5d150abd614ade404f4c9e);
#
#
#         var popup_3d65f004ab5c7d7bff319aca23b9ca48 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4428f6773926bba30ccee1f382d9ba14 = $(`&lt;div id=&quot;html_4428f6773926bba30ccee1f382d9ba14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Localização&lt;/div&gt;`)[0];
#                 popup_3d65f004ab5c7d7bff319aca23b9ca48.setContent(html_4428f6773926bba30ccee1f382d9ba14);
#
#
#
#         marker_d68d531e23cfed4d3050282cdce90361.bindPopup(popup_3d65f004ab5c7d7bff319aca23b9ca48)
#         ;
#
#
#
#
#             var marker_d2506a3c8b3d4bd32754736a8cda162d = L.marker(
#                 [37.75402, -122.45805],
#                 {}
#             ).addTo(map_56d7ebb77a5d150abd614ade404f4c9e);
#
#
#         var popup_0b48f7ebdb96897c05e057c07bd036c8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_712ca642b08fdeb3959458ec4ba31714 = $(`&lt;div id=&quot;html_712ca642b08fdeb3959458ec4ba31714&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Localização&lt;/div&gt;`)[0];
#                 popup_0b48f7ebdb96897c05e057c07bd036c8.setContent(html_712ca642b08fdeb3959458ec4ba31714);
#
#
#
#         marker_d2506a3c8b3d4bd32754736a8cda162d.bindPopup(popup_0b48f7ebdb96897c05e057c07bd036c8)
#         ;
#
#
#
#
#             var marker_3314bb5356996caf43182fe5f65ea72d = L.marker(
#                 [37.74511, -122.42102],
#                 {}
#             ).addTo(map_56d7ebb77a5d150abd614ade404f4c9e);
#
#
#         var popup_4b1dfa418386a3e4369a5e455d4c3a1e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e81b67a6329e0c00a8b2ead370ad8c3e = $(`&lt;div id=&quot;html_e81b67a6329e0c00a8b2ead370ad8c3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Localização&lt;/div&gt;`)[0];
#                 popup_4b1dfa418386a3e4369a5e455d4c3a1e.setContent(html_e81b67a6329e0c00a8b2ead370ad8c3e);
#
#
#
#         marker_3314bb5356996caf43182fe5f65ea72d.bindPopup(popup_4b1dfa418386a3e4369a5e455d4c3a1e)
#         ;
#
#
#
#
#             var marker_ce2e0b37c34160964f16604ccd93f51f = L.marker(
#                 [37.76669, -122.4525],
#                 {}
#             ).addTo(map_56d7ebb77a5d150abd614ade404f4c9e);
#
#
#         var popup_3fa0932b5121ae83b49c65afe18b0946 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_20bd8e41e3b9c1ca9dc669a0d954c4af = $(`&lt;div id=&quot;html_20bd8e41e3b9c1ca9dc669a0d954c4af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Localização&lt;/div&gt;`)[0];
#                 popup_3fa0932b5121ae83b49c65afe18b0946.setContent(html_20bd8e41e3b9c1ca9dc669a0d954c4af);
#
#
#
#         marker_ce2e0b37c34160964f16604ccd93f51f.bindPopup(popup_3fa0932b5121ae83b49c65afe18b0946)
#         ;
#
#
#
#
#             var marker_122cbb957cf27e78bb24fccbb7189aca = L.marker(
#                 [37.76487, -122.45183],
#                 {}
#             ).addTo(map_56d7ebb77a5d150abd614ade404f4c9e);
#
#
#         var popup_60ce9d0becc44e2dec7e3d307e734c33 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_516d4eae2372a812346bdcd76641a4bc = $(`&lt;div id=&quot;html_516d4eae2372a812346bdcd76641a4bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Localização&lt;/div&gt;`)[0];
#                 popup_60ce9d0becc44e2dec7e3d307e734c33.setContent(html_516d4eae2372a812346bdcd76641a4bc);
#
#
#
#         marker_122cbb957cf27e78bb24fccbb7189aca.bindPopup(popup_60ce9d0becc44e2dec7e3d307e734c33)
#         ;
#
#
#
#
#             var marker_8508a22fab098204577f2ebccf8bfc18 = L.marker(
#                 [37.75919, -122.42237],
#                 {}
#             ).addTo(m

# %% [markdown]
# #Modelo

# %%
rentals_dummies=pd.get_dummies(rentals)
X=rentals_dummies.drop(columns=['price'])
y=rentals_dummies.price

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size = 0.2, random_state = 1)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
pca = PCA(0.95)
X_train = pca.fit_transform(X_train)
X_test=pca.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor


model = RandomForestRegressor()

model.fit(X_train, y_train)
y_predict = model.predict(X_test)
print(r2_score(y_test,y_predict)*100)
# Out:
# 81.61746073254537

# %%
result={'y':y_test,'Predict':y_predict}
result_df=pd.DataFrame(result)

# %%
print(result_df.head(30))
# Out:
#           y  Predict
# 4271   82.0   105.72
# 1649  350.0   287.11
# 3205   75.0    99.22
# 3131   40.0   153.29
# 7140  180.0   207.03
# 6403  217.0   279.21
# 965   143.0   218.15
# 3431  350.0   316.50
# 7087   39.0    41.80
# 6499  235.0   420.41
# 7445  122.0   108.25
# 3640  150.0   298.62
# 1262  250.0   368.44
# 4004   89.0    82.82
# 4668   90.0    82.07
# 7694  200.0   163.02
# 5292   90.0    84.78
# 3552   70.0    67.18
# 462    70.0   106.23
# 6759  310.0   459.45
# 5458  600.0   278.86
# 6962  240.0   169.91
# 1460  250.0   159.42
# 3087   80.0    81.66
# 5705   79.0   130.44
# 3372  149.0   129.43
# 6400  196.0   221.38
# 4997  110.0   134.83
# 5663  155.0   177.69
# 1210  150.0   159.96

# %% [markdown]
# #Encontrando um modelo melhor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, make_scorer

param_grid=[{"n_estimators":[3,10,30], "max_features":[2,4,6,8], 'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]}]

# Criar o modelo de RandomForestRegressor
regressor = RandomForestRegressor()

# Definir a métrica de avaliação
scorer = make_scorer(mean_squared_error, greater_is_better=False)

# Criar o objeto GridSearchCV
grid_search = GridSearchCV(regressor, param_grid, scoring=scorer, cv=5)

# Treinar o modelo usando GridSearchCV
grid_search.fit(X_train, y_train)

# Obter os melhores hiperparâmetros encontrados
best_params = grid_search.best_params_

# Treinar o modelo final com os melhores hiperparâmetros
final_regressor = RandomForestRegressor(**best_params)
final_regressor.fit(X_train, y_train)

# Fazer previsões usando o modelo final
y_pred = final_regressor.predict(X_test)
print(r2_score(y_test,y_pred)*100)
# Out:
# 88.98507912149026

# %%
print(final_regressor)
# Out:
# RandomForestRegressor(max_features=4, n_estimators=30)

# %%
final_regressor=RandomForestRegressor(max_features=6, n_estimators=30)
final_regressor.fit(X_train, y_train)
y_pred = final_regressor.predict(X_test)
print(r2_score(y_test,y_pred)*100)
# Out:
# 90.79564354186014

# %%
result={'y':y_test,'Predict':y_pred}
result_df=pd.DataFrame(result)

# %%
print(result_df.head(30))
# Out:
#           y     Predict
# 4271   82.0  112.500000
# 1649  350.0  285.600000
# 3205   75.0   99.333333
# 3131   40.0  132.833333
# 7140  180.0  242.733333
# 6403  217.0  270.700000
# 965   143.0  158.033333
# 3431  350.0  315.000000
# 7087   39.0   45.633333
# 6499  235.0  355.200000
# 7445  122.0  105.066667
# 3640  150.0  314.600000
# 1262  250.0  364.800000
# 4004   89.0   88.266667
# 4668   90.0   81.966667
# 7694  200.0  170.400000
# 5292   90.0   83.366667
# 3552   70.0   66.033333
# 462    70.0   91.000000
# 6759  310.0  476.000000
# 5458  600.0  288.366667
# 6962  240.0  157.266667
# 1460  250.0  162.566667
# 3087   80.0   80.366667
# 5705   79.0  126.466667
# 3372  149.0  120.766667
# 6400  196.0  248.266667
# 4997  110.0  133.000000
# 5663  155.0  172.833333
# 1210  150.0  152.800000

# %% [markdown]
# #EPC9

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder


num_pipeline=Pipeline([("scaler", StandardScaler()),
                        ("pca", PCA())
                       ])

cat_pipeline=Pipeline([("encoder", OneHotEncoder())
                       ])

# %%
rentals.info()
print(rentals.property_type.value_counts())
print(rentals.room_type.value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7434 entries, 0 to 8110
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   latitude        7434 non-null   float64
#  1   longitude       7434 non-null   float64
#  2   property_type   7434 non-null   object
#  3   room_type       7434 non-null   object
#  4   bathrooms       7434 non-null   float64
#  5   bedrooms        7434 non-null   int64
#  6   minimum_nights  7434 non-null   float64
#  7   price           7434 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 522.7+ KB
# Apartment             2948
# House                 2134
# Condominium            806
# Guest suite            560
# Boutique hotel         250
# Hotel                  149
# Townhouse              125
# Serviced apartment     108
# Loft                    80
# Hostel                  75
# Guesthouse              40
# Bed and breakfast       38
# Aparthotel              35
# Other                   24
# Bungalow                17
# Cottage                 11
# Resort                  11
# Villa                    8
# Castle                   4
# Cabin                    3
# Tiny house               3
# Earth house              2
# In-law                   1
# Dome house               1
# Hut                      1
# Name: property_type, dtype: int64
# Entire home/apt    4239
# Private room       2792
# Shared room         221
# Hotel room          182
# Name: room_type, dtype: int64

# %%
X_num=rentals.drop(columns=['price', "property_type","room_type"])
X_cat=rentals[["property_type","room_type"]]
y_final=rentals.price
print(X_num.columns)
print(X_cat.columns)
# Out:
# Index(['latitude', 'longitude', 'bathrooms', 'bedrooms', 'minimum_nights'], dtype='object')
# Index(['property_type', 'room_type'], dtype='object')

# %%
from sklearn.compose import ColumnTransformer

pipeline=ColumnTransformer([("num_pipeline",num_pipeline,[0,1,4,5,6]),
                           ("cat_pipeline", cat_pipeline,[2,3])])
rentals_prepared=pipeline.fit_transform(rentals.drop(columns=['price']))
print(rentals_prepared)
# Out:
#   (0, 0)	-0.29232372237099147
#   (0, 1)	-0.9048500009602105
#   (0, 2)	-0.8475329825203883
#   (0, 3)	-0.49661018131388324
#   (0, 4)	-0.3557390239953838
#   (0, 6)	1.0
#   (0, 30)	1.0
#   (1, 0)	-1.1537897580146672
#   (1, 1)	-1.149370832788107
#   (1, 2)	-0.3341032779064676
#   (1, 3)	-0.6817246689929941
#   (1, 4)	0.008206432889962402
#   (1, 20)	1.0
#   (1, 32)	1.0
#   (2, 0)	-0.25334319018070217
#   (2, 1)	0.38251405902831015
#   (2, 2)	0.9043534813584807
#   (2, 3)	1.3391256732598629
#   (2, 4)	-0.16857560737183863
#   (2, 6)	1.0
#   (2, 30)	1.0
#   (3, 0)	-0.18785960732501175
#   (3, 1)	2.22819259131813
#   (3, 2)	0.20069304632828053
#   (3, 3)	-1.0468252735278634
#   :	:
#   (7430, 3)	-0.4273843839690834
#   (7430, 4)	-0.5591512570644638
#   (7430, 12)	1.0
#   (7430, 30)	1.0
#   (7431, 0)	0.4863068225265578
#   (7431, 1)	0.5238462292758745
#   (7431, 2)	-0.10281073312810061
#   (7431, 3)	1.853812759105712
#   (7431, 4)	1.3734994010932893
#   (7431, 21)	1.0
#   (7431, 32)	1.0
#   (7432, 0)	1.3694867632753311
#   (7432, 1)	0.14307898416953635
#   (7432, 2)	0.516508833560167
#   (7432, 3)	0.27306605589511984
#   (7432, 4)	-0.17043323397829097
#   (7432, 6)	1.0
#   (7432, 30)	1.0
#   (7433, 0)	-2.6743914537823272
#   (7433, 1)	-0.9523749225250607
#   (7433, 2)	-0.25405020990059124
#   (7433, 3)	1.1307417439197072
#   (7433, 4)	0.18486189151343593
#   (7433, 20)	1.0
#   (7433, 32)	1.0

# %%
x_TRAIN,x_TEST,y_TRAIN,y_TEST=train_test_split(rentals_prepared,rentals.price,test_size = 0.2, random_state = 1)

# %%
regressor=final_regressor

regressor.fit(x_TRAIN, y_TRAIN)

# Fazer previsões usando o modelo final
y_pred = regressor.predict(x_TEST)
r2_final_regressor=r2_score(y_TEST,y_pred)*100
print(r2_final_regressor)
# Out:
# 79.10689264968664

# %%
result_final={'y':y_TEST,'Predict':y_pred}
result_df_final=pd.DataFrame(result_final)

# %%
result_df_final.head(20)
# Out:
#           y     Predict
# 4271   82.0   91.000000
# 1649  350.0  260.633333
# 3205   75.0   83.600000
# 3131   40.0  184.100000
# 7140  180.0  231.533333
# 6403  217.0  261.766667
# 965   143.0  183.933333
# 3431  350.0  327.166667
# 7087   39.0   46.100000
# 6499  235.0  385.266667
# 7445  122.0  111.466667
# 3640  150.0  263.433333
# 1262  250.0  319.166667
# 4004   89.0  100.166667
# 4668   90.0   87.200000
# 7694  200.0  249.500000
# 5292   90.0   74.400000
# 3552   70.0   67.600000
# 462    70.0   96.500000
# 6759  310.0  405.600000

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

models = [
    LinearRegression(),
    RandomForestRegressor(),
    SVR()
]

results=[]
for model in models:

    model.fit(x_TRAIN, y_TRAIN)

    predictions = model.predict(x_TEST)

    #mse = mean_squared_error(y_TEST, predictions)
    r2 = r2_score(y_TEST, predictions)*100

    print("Modelo:", model)
    #print("MSE:", mse)
    print("R^2:", r2)
    results.append(r2)
    result_df_loop={'y':y_TEST,'Predict':predictions}
    print(pd.DataFrame(result_df_loop).head(10))
    print("-----------------------")
# Out:
# Modelo: LinearRegression()
# R^2: 8.671359114633749
#           y     Predict
# 4271   82.0   45.301188
# 1649  350.0  294.812746
# 3205   75.0  177.576059
# 3131   40.0   25.171940
# 7140  180.0  230.806504
# 6403  217.0  411.476052
# 965   143.0  104.466498
# 3431  350.0  350.630257
# 7087   39.0   34.683206
# 6499  235.0  367.763471
# -----------------------
# Modelo: RandomForestRegressor()
# R^2: 59.21967847771543
#           y  Predict
# 4271   82.0    94.09
# 1649  350.0   311.80
# 3205   75.0   106.42
# 3131   40.0   183.38
# 7140  180.0   224.03
# 6403  217.0   261.99
# 965   143.0   177.70
# 3431  350.0   326.10
# 7087   39.0    53.19
# 6499  235.0   426.54
# -----------------------
# Modelo: SVR()
# R^2: 2.605264866021595
#           y     Predict
# 4271   82.0   93.166492
# 1649  350.0  216.692267
# 3205   75.0  150.860397
# 3131   40.0   77.431505
# 7140  180.0  151.922097
# 6403  217.0  159.196162
# 965   143.0  140.335547
# 3431  350.0  153.454453
# 7087   39.0  113.141898
# 6499  235.0  237.576783
# -----------------------

# %%
models.append(final_regressor)
results.append(r2_final_regressor)

# %%
results_df=pd.DataFrame({"Modelo":models, "r^2 score": results})
print(results_df)
# Out:
#                                               Modelo  r^2 score
# 0                                 LinearRegression()   8.671359
# 1  (DecisionTreeRegressor(max_features=1.0, rando...  59.219678
# 2                                              SVR()   2.605265
# 3  (DecisionTreeRegressor(max_features=6, random_...  79.106893

# %%
import matplotlib.pyplot as plt

# Definindo os modelos e suas pontuações
modelos = ['LinearRegression', 'SVR', 'RandomForestRegressor']
pontuacoes = [8.671359, 2.605265, 89.78]

# Criando o gráfico de barras com cores personalizadas
cores = ['#808080', '#A9A9A9', '#D3D3D3']
plt.bar(modelos, pontuacoes, color=cores)

# Adicionando rótulos aos eixos
plt.xlabel('Modelos', fontsize=12)
plt.ylabel('Pontuações', fontsize=12)

# Definindo limites para os eixos
plt.ylim(0, 100)

# Adicionando valores nas barras
for i, pontuacao in enumerate(pontuacoes):
    plt.text(i, pontuacao + 1, str(pontuacao), ha='center', va='bottom')

# Removendo bordas desnecessárias do gráfico
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Personalizando o estilo dos ticks nos eixos
plt.tick_params(axis='x', which='both', bottom=False, top=False)
plt.tick_params(axis='y', which='both', left=False, right=False)

# Ajustando o espaçamento entre as barras
plt.tight_layout()

# Exibindo o gráfico
plt.show()

# %% [markdown]
# # Deploy do modelo

# %%
import pickle

model_file="model.pickle"
pickle.dump(regressor, open(model_file,'wb'))

pipeline_file="pipeline.pickle"
pickle.dump(pipeline, open(pipeline_file,'wb'))
